# %%
import pandas
import numpy as np
from matplotlib import pyplot as plt

###cvlc###
#cpu_cvlc_h264
cpu_cvlc_h264_trial1=pandas.read_csv('raw_data/cpu_cvlch264_trial1')
cpu_cvlc_h264_trial2=pandas.read_csv('raw_data/cpu_cvlch264_trial2')
cpu_cvlc_h264_trial3=pandas.read_csv('raw_data/cpu_cvlch264_trial3')
cpu_cvlc_h264_trial4=pandas.read_csv('raw_data/cpu_cvlch264_trial4')
cpu_cvlc_h264_trial5=pandas.read_csv('raw_data/cpu_cvlch264_trial5')
cpu_cvlc_h264_trial6=pandas.read_csv('raw_data/cpu_cvlch264_trial6')
cpu_cvlc_h264_trial7=pandas.read_csv('raw_data/cpu_cvlch264_trial7')

#memory_cvlc_h264
memory_cvlc_h264_trial1=pandas.read_csv('raw_data/memory_cvlch264_trial1')
memory_cvlc_h264_trial2=pandas.read_csv('raw_data/memory_cvlch264_trial2')
memory_cvlc_h264_trial3=pandas.read_csv('raw_data/memory_cvlch264_trial3')
memory_cvlc_h264_trial4=pandas.read_csv('raw_data/memory_cvlch264_trial4')
memory_cvlc_h264_trial5=pandas.read_csv('raw_data/memory_cvlch264_trial5')
memory_cvlc_h264_trial6=pandas.read_csv('raw_data/memory_cvlch264_trial6')
memory_cvlc_h264_trial7=pandas.read_csv('raw_data/memory_cvlch264_trial7')

#network_receive_cvlc_h264
network_receive_cvlc_h264_trial1=pandas.read_csv('raw_data/net_receive_cvlch264_trial1')
network_receive_cvlc_h264_trial2=pandas.read_csv('raw_data/net_receive_cvlch264_trial2')
network_receive_cvlc_h264_trial3=pandas.read_csv('raw_data/net_receive_cvlch264_trial3')
network_receive_cvlc_h264_trial4=pandas.read_csv('raw_data/net_receive_cvlch264_trial4')
network_receive_cvlc_h264_trial5=pandas.read_csv('raw_data/net_receive_cvlch264_trial5')
network_receive_cvlc_h264_trial6=pandas.read_csv('raw_data/net_receive_cvlch264_trial6')
network_receive_cvlc_h264_trial7=pandas.read_csv('raw_data/net_receive_cvlch264_trial7')

#network_transmit_cvlc_h264
network_transmit_cvlc_h264_trial1=pandas.read_csv('raw_data/net_transmit')
network_transmit_cvlc_h264_trial2=pandas.read_csv('raw_data/net_transmit')                                                
network_transmit_cvlc_h264_trial3=pandas.read_csv('raw_data/net_transmit')                                                
network_transmit_cvlc_h264_trial4=pandas.read_csv('raw_data/net_transmit')
network_transmit_cvlc_h264_trial5=pandas.read_csv('raw_data/net_transmit')
network_transmit_cvlc_h264_trial6=pandas.read_csv('raw_data/net_transmit')
network_transmit_cvlc_h264_trial7=pandas.read_csv('raw_data/net_transmit')
                                                  
#cpu_cvlc_mjpeg
cpu_cvlc_mjpeg_trial1=pandas.read_csv('raw_data/cpu_cvlcmjpeg_trial1')
cpu_cvlc_mjpeg_trial2=pandas.read_csv('raw_data/cpu_cvlcmjpeg_trial2')
cpu_cvlc_mjpeg_trial3=pandas.read_csv('raw_data/cpu_cvlcmjpeg_trial3')
cpu_cvlc_mjpeg_trial4=pandas.read_csv('raw_data/cpu_cvlcmjpeg_trial4')
cpu_cvlc_mjpeg_trial5=pandas.read_csv('raw_data/cpu_cvlcmjpeg_trial5')
cpu_cvlc_mjpeg_trial6=pandas.read_csv('raw_data/cpu_cvlcmjpeg_trial6')
cpu_cvlc_mjpeg_trial7=pandas.read_csv('raw_data/cpu_cvlcmjpeg_trial7')

#memory_cvlc_mjpeg
memory_cvlc_mjpeg_trial1=pandas.read_csv('raw_data/memory_cvlcmjpeg_trial1')
memory_cvlc_mjpeg_trial2=pandas.read_csv('raw_data/memory_cvlcmjpeg_trial2')
memory_cvlc_mjpeg_trial3=pandas.read_csv('raw_data/memory_cvlcmjpeg_trial3')
memory_cvlc_mjpeg_trial4=pandas.read_csv('raw_data/memory_cvlcmjpeg_trial4')
memory_cvlc_mjpeg_trial5=pandas.read_csv('raw_data/memory_cvlcmjpeg_trial5')
memory_cvlc_mjpeg_trial6=pandas.read_csv('raw_data/memory_cvlcmjpeg_trial6')
memory_cvlc_mjpeg_trial7=pandas.read_csv('raw_data/memory_cvlcmjpeg_trial7')

#network_receive_cvlc_mjpeg
network_receive_cvlc_mjpeg_trial1=pandas.read_csv('raw_data/net_recieve_cvlcmjpeg_trail1')
network_receive_cvlc_mjpeg_trial2=pandas.read_csv('raw_data/net_recieve_cvlcmjpeg_trail2')
network_receive_cvlc_mjpeg_trial3=pandas.read_csv('raw_data/net_recieve_cvlcmjpeg_trail3')
network_receive_cvlc_mjpeg_trial4=pandas.read_csv('raw_data/net_recieve_cvlcmjpeg_trail4')
network_receive_cvlc_mjpeg_trial5=pandas.read_csv('raw_data/net_recieve_cvlcmjpeg_trail5')
network_receive_cvlc_mjpeg_trial6=pandas.read_csv('raw_data/net_recieve_cvlcmjpeg_trail6')
network_receive_cvlc_mjpeg_trial7=pandas.read_csv('raw_data/net_recieve_cvlcmjpeg_trail7')

#network_transmit_cvlc_mjpeg
network_transmit_cvlc_mjpeg_trial1=pandas.read_csv('raw_data/net_transmit_cvlcmjpeg_trail1')
network_transmit_cvlc_mjpeg_trial2=pandas.read_csv('raw_data/net_transmit_cvlcmjpeg_trail2')
network_transmit_cvlc_mjpeg_trial3=pandas.read_csv('raw_data/net_transmit_cvlcmjpeg_trail3')
network_transmit_cvlc_mjpeg_trial4=pandas.read_csv('raw_data/net_transmit_cvlcmjpeg_trail4')
network_transmit_cvlc_mjpeg_trial5=pandas.read_csv('raw_data/net_transmit_cvlcmjpeg_trail5')
network_transmit_cvlc_mjpeg_trial6=pandas.read_csv('raw_data/net_transmit_cvlcmjpeg_trail6')
network_transmit_cvlc_mjpeg_trial7=pandas.read_csv('raw_data/net_transmit_cvlcmjpeg_trail7')

###ffmpeg###
#cpu_ffmpeg_h264
cpu_ffmpeg_h264_trial1=pandas.read_csv('raw_data/cpu_ffmpegh264_trail1')
cpu_ffmpeg_h264_trial2=pandas.read_csv('raw_data/cpu_ffmpegh264_trail2')
cpu_ffmpeg_h264_trial3=pandas.read_csv('raw_data/cpu_ffmpegh264_trail3')
cpu_ffmpeg_h264_trial4=pandas.read_csv('raw_data/cpu_ffmpegh264_trail4')
cpu_ffmpeg_h264_trial5=pandas.read_csv('raw_data/cpu_ffmpegh264_trail5')
cpu_ffmpeg_h264_trial6=pandas.read_csv('raw_data/cpu_ffmpegh264_trail6')
cpu_ffmpeg_h264_trial7=pandas.read_csv('raw_data/cpu_ffmpegh264_trail7')

#memory_ffmpeg_h264
memory_ffmpeg_h264_trial1=pandas.read_csv('raw_data/memory_ffmpegh264_trail1')
memory_ffmpeg_h264_trial2=pandas.read_csv('raw_data/memory_ffmpegh264_trail2')
memory_ffmpeg_h264_trial3=pandas.read_csv('raw_data/memory_ffmpegh264_trail3')
memory_ffmpeg_h264_trial4=pandas.read_csv('raw_data/memory_ffmpegh264_trail4')
memory_ffmpeg_h264_trial5=pandas.read_csv('raw_data/memory_ffmpegh264_trail5')
memory_ffmpeg_h264_trial6=pandas.read_csv('raw_data/memory_ffmpegh264_trail6')
memory_ffmpeg_h264_trial7=pandas.read_csv('raw_data/memory_ffmpegh264_trail7')

#network_receive_ffmpeg_h264
network_receive_ffmpeg_h264_trial1=pandas.read_csv('raw_data/net_receive_ffmpegh264_trail1')
network_receive_ffmpeg_h264_trial2=pandas.read_csv('raw_data/net_receive_ffmpegh264_trail2')
network_receive_ffmpeg_h264_trial3=pandas.read_csv('raw_data/net_receive_ffmpegh264_trail3')
network_receive_ffmpeg_h264_trial4=pandas.read_csv('raw_data/net_receive_ffmpegh264_trail4')
network_receive_ffmpeg_h264_trial5=pandas.read_csv('raw_data/net_receive_ffmpegh264_trail5')
network_receive_ffmpeg_h264_trial6=pandas.read_csv('raw_data/net_receive_ffmpegh264_trail6')
network_receive_ffmpeg_h264_trial7=pandas.read_csv('raw_data/net_receive_ffmpegh264_trail7')

#network_transmit_ffmpeg_h264
network_transmit_ffmpeg_h264_trial1=pandas.read_csv('raw_data/net_transmit_ffmpegh264_trail1')
network_transmit_ffmpeg_h264_trial2=pandas.read_csv('raw_data/net_transmit_ffmpegh264_trail2')
network_transmit_ffmpeg_h264_trial3=pandas.read_csv('raw_data/net_transmit_ffmpegh264_trail3')
network_transmit_ffmpeg_h264_trial4=pandas.read_csv('raw_data/net_transmit_ffmpegh264_trail4')
network_transmit_ffmpeg_h264_trial5=pandas.read_csv('raw_data/net_transmit_ffmpegh264_trail5')
network_transmit_ffmpeg_h264_trial6=pandas.read_csv('raw_data/net_transmit_ffmpegh264_trail6')
network_transmit_ffmpeg_h264_trial7=pandas.read_csv('raw_data/net_transmit_ffmpegh264_trail7')

#cpu_ffmpeg_mjpeg
cpu_ffmpeg_mjpeg_trial1=pandas.read_csv('raw_data/cpu_ffmpegmjpeg_trail1')
cpu_ffmpeg_mjpeg_trial2=pandas.read_csv('raw_data/cpu_ffmpegmjpeg_trail2')
cpu_ffmpeg_mjpeg_trial3=pandas.read_csv('raw_data/cpu_ffmpegmjpeg_trail3')
cpu_ffmpeg_mjpeg_trial4=pandas.read_csv('raw_data/cpu_ffmpegmjpeg_trail4')
cpu_ffmpeg_mjpeg_trial5=pandas.read_csv('raw_data/cpu_ffmpegmjpeg_trail5')
cpu_ffmpeg_mjpeg_trial6=pandas.read_csv('raw_data/cpu_ffmpegmjpeg_trail6')
cpu_ffmpeg_mjpeg_trial7=pandas.read_csv('raw_data/cpu_ffmpegmjpeg_trail7')

#memory_ffmpeg_mjpeg
memory_ffmpeg_mjpeg_trial1=pandas.read_csv('raw_data/memory_ffmpegmjpeg_trail1')
memory_ffmpeg_mjpeg_trial2=pandas.read_csv('raw_data/memory_ffmpegmjpeg_trail2')
memory_ffmpeg_mjpeg_trial3=pandas.read_csv('raw_data/memory_ffmpegmjpeg_trail3')
memory_ffmpeg_mjpeg_trial4=pandas.read_csv('raw_data/memory_ffmpegmjpeg_trail4')
memory_ffmpeg_mjpeg_trial5=pandas.read_csv('raw_data/memory_ffmpegmjpeg_trail5')
memory_ffmpeg_mjpeg_trial6=pandas.read_csv('raw_data/memory_ffmpegmjpeg_trail6')
memory_ffmpeg_mjpeg_trial7=pandas.read_csv('raw_data/memory_ffmpegmjpeg_trail7')

#network_receive_ffmpeg_mjpeg
network_receive_ffmpeg_mjpeg_trial1=pandas.read_csv('raw_data/net_receive_ffmpegmjpeg_trail1')
network_receive_ffmpeg_mjpeg_trial2=pandas.read_csv('raw_data/net_receive_ffmpegmjpeg_trail2')
network_receive_ffmpeg_mjpeg_trial3=pandas.read_csv('raw_data/net_receive_ffmpegmjpeg_trail3')
network_receive_ffmpeg_mjpeg_trial4=pandas.read_csv('raw_data/net_receive_ffmpegmjpeg_trail4')
network_receive_ffmpeg_mjpeg_trial5=pandas.read_csv('raw_data/net_receive_ffmpegmjpeg_trail5')
network_receive_ffmpeg_mjpeg_trial6=pandas.read_csv('raw_data/net_receive_ffmpegmjpeg_trail6')
network_receive_ffmpeg_mjpeg_trial7=pandas.read_csv('raw_data/net_receive_ffmpegmjpeg_trail7')

#network_transmit_ffmpeg_mjpeg
network_transmit_ffmpeg_mjpeg_trial1=pandas.read_csv('raw_data/net_transmit_ffmpegmjpeg_trail1')
network_transmit_ffmpeg_mjpeg_trial2=pandas.read_csv('raw_data/net_transmit_ffmpegmjpeg_trail2')
network_transmit_ffmpeg_mjpeg_trial3=pandas.read_csv('raw_data/net_transmit_ffmpegmjpeg_trail3')
network_transmit_ffmpeg_mjpeg_trial4=pandas.read_csv('raw_data/net_transmit_ffmpegmjpeg_trail4')
network_transmit_ffmpeg_mjpeg_trial5=pandas.read_csv('raw_data/net_transmit_ffmpegmjpeg_trail5')
network_transmit_ffmpeg_mjpeg_trial6=pandas.read_csv('raw_data/net_transmit_ffmpegmjpeg_trail6')
network_transmit_ffmpeg_mjpeg_trial7=pandas.read_csv('raw_data/net_transmit_ffmpegmjpeg_trail7')

###mjpgstreamer###
#cpu_mjpgstreamer
cpu_mjpgstreamer_trial1=pandas.read_csv('raw_data/cpu_mjpgstreamer_trail1')
cpu_mjpgstreamer_trial2=pandas.read_csv('raw_data/cpu_mjpgstreamer_trail2')
cpu_mjpgstreamer_trial3=pandas.read_csv('raw_data/cpu_mjpgstreamer_trail3')
cpu_mjpgstreamer_trial4=pandas.read_csv('raw_data/cpu_mjpgstreamer_trail4')
cpu_mjpgstreamer_trial5=pandas.read_csv('raw_data/cpu_mjpgstreamer_trail5')
cpu_mjpgstreamer_trial6=pandas.read_csv('raw_data/cpu_mjpgstreamer_trail6')
cpu_mjpgstreamer_trial7=pandas.read_csv('raw_data/cpu_mjpgstreamer_trail7')

#memory_mjpgstreamer
memory_mjpgstreamer_trial1=pandas.read_csv('raw_data/memory_mjpgstreamer_trail1')
memory_mjpgstreamer_trial2=pandas.read_csv('raw_data/memory_mjpgstreamer_trail2')
memory_mjpgstreamer_trial3=pandas.read_csv('raw_data/memory_mjpgstreamer_trail3')
memory_mjpgstreamer_trial4=pandas.read_csv('raw_data/memory_mjpgstreamer_trail4')
memory_mjpgstreamer_trial5=pandas.read_csv('raw_data/memory_mjpgstreamer_trail5')
memory_mjpgstreamer_trial6=pandas.read_csv('raw_data/memory_mjpgstreamer_trail6')
memory_mjpgstreamer_trial7=pandas.read_csv('raw_data/memory_mjpgstreamer_trail7')

#network_receive_mjpgstreamer
network_receive_mjpgstreamer_trial1=pandas.read_csv('raw_data/net_recieve_mjpgstreamer_trail1')
network_receive_mjpgstreamer_trial2=pandas.read_csv('raw_data/net_recieve_mjpgstreamer_trail2')
network_receive_mjpgstreamer_trial3=pandas.read_csv('raw_data/net_recieve_mjpgstreamer_trail3')
network_receive_mjpgstreamer_trial4=pandas.read_csv('raw_data/net_recieve_mjpgstreamer_trail4')
network_receive_mjpgstreamer_trial5=pandas.read_csv('raw_data/net_recieve_mjpgstreamer_trail5')
network_receive_mjpgstreamer_trial6=pandas.read_csv('raw_data/net_recieve_mjpgstreamer_trail6')
network_receive_mjpgstreamer_trial7=pandas.read_csv('raw_data/net_recieve_mjpgstreamer_trail7')

#network_transmit_mjpgstreamer
network_transmit_mjpgstreamer_trial1=pandas.read_csv('raw_data/net_transmit_mjpgstreamer_trail1')
network_transmit_mjpgstreamer_trial2=pandas.read_csv('raw_data/net_transmit_mjpgstreamer_trail2')
network_transmit_mjpgstreamer_trial3=pandas.read_csv('raw_data/net_transmit_mjpgstreamer_trail3')
network_transmit_mjpgstreamer_trial4=pandas.read_csv('raw_data/net_transmit_mjpgstreamer_trail4')
network_transmit_mjpgstreamer_trial5=pandas.read_csv('raw_data/net_transmit_mjpgstreamer_trail5')
network_transmit_mjpgstreamer_trial6=pandas.read_csv('raw_data/net_transmit_mjpgstreamer_trail6')

###gstreamer###
#cpu_gstreamer_h264
cpu_gstreamer_h264_trial1=pandas.read_csv('raw_data/cpu_gstreamerh264_trail1')
cpu_gstreamer_h264_trial2=pandas.read_csv('raw_data/cpu_gstreamerh264_trail2')
cpu_gstreamer_h264_trial3=pandas.read_csv('raw_data/cpu_gstreamerh264_trail3')
cpu_gstreamer_h264_trial4=pandas.read_csv('raw_data/cpu_gstreamerh264_trail4')
cpu_gstreamer_h264_trial5=pandas.read_csv('raw_data/cpu_gstreamerh264_trail5')
cpu_gstreamer_h264_trial6=pandas.read_csv('raw_data/cpu_gstreamerh264_trail6')

#memory_gstreamer_h264
memory_gstreamer_h264_trial1=pandas.read_csv('raw_data/memory_gstreamerh264_trail1')
memory_gstreamer_h264_trial2=pandas.read_csv('raw_data/memory_gstreamerh264_trail2')
memory_gstreamer_h264_trial3=pandas.read_csv('raw_data/memory_gstreamerh264_trail3')
memory_gstreamer_h264_trial4=pandas.read_csv('raw_data/memory_gstreamerh264_trail4')
memory_gstreamer_h264_trial5=pandas.read_csv('raw_data/memory_gstreamerh264_trail5')
memory_gstreamer_h264_trial6=pandas.read_csv('raw_data/memory_gstreamerh264_trail6')
memory_gstreamer_h264_trial7=pandas.read_csv('raw_data/memory_gstreamerh264_trail7')

#network_receive_gstreamer_h264
network_receive_gstreamer_h264_trial1=pandas.read_csv('raw_data/net_recieve_gstreamerh264_trail1')
network_receive_gstreamer_h264_trial2=pandas.read_csv('raw_data/net_recieve_gstreamerh264_trail2')
network_receive_gstreamer_h264_trial3=pandas.read_csv('raw_data/net_recieve_gstreamerh264_trail3')
network_receive_gstreamer_h264_trial4=pandas.read_csv('raw_data/net_recieve_gstreamerh264_trail4')
network_receive_gstreamer_h264_trial5=pandas.read_csv('raw_data/net_recieve_gstreamerh264_trail5')
network_receive_gstreamer_h264_trial6=pandas.read_csv('raw_data/net_recieve_gstreamerh264_trail6')
network_receive_gstreamer_h264_trial7=pandas.read_csv('raw_data/net_recieve_gstreamerh264_trail7')

#network_transmit_gstreamer_h264
network_transmit_gstreamer_h264_trial1=pandas.read_csv('raw_data/net_transmit_gstreamerh264_trail1')
network_transmit_gstreamer_h264_trial2=pandas.read_csv('raw_data/net_transmit_gstreamerh264_trail2')
network_transmit_gstreamer_h264_trial3=pandas.read_csv('raw_data/net_transmit_gstreamerh264_trail3')
network_transmit_gstreamer_h264_trial4=pandas.read_csv('raw_data/net_transmit_gstreamerh264_trail4')
network_transmit_gstreamer_h264_trial5=pandas.read_csv('raw_data/net_transmit_gstreamerh264_trail5')
network_transmit_gstreamer_h264_trial6=pandas.read_csv('raw_data/net_transmit_gstreamerh264_trail6')
network_transmit_gstreamer_h264_trial7=pandas.read_csv('raw_data/net_transmit_gstreamerh264_trail7')

#cpu_gstreamer_mjpeg
cpu_gstreamer_mjpeg_trial1=pandas.read_csv('raw_data/cpu_gstreamer_mjpeg_trail1')
cpu_gstreamer_mjpeg_trial2=pandas.read_csv('raw_data/cpu_gstreamer_mjpeg_trail2')
cpu_gstreamer_mjpeg_trial3=pandas.read_csv('raw_data/cpu_gstreamer_mjpeg_trail3')
cpu_gstreamer_mjpeg_trial4=pandas.read_csv('raw_data/cpu_gstreamer_mjpeg_trail4')
cpu_gstreamer_mjpeg_trial5=pandas.read_csv('raw_data/cpu_gstreamer_mjpeg_trail5')
cpu_gstreamer_mjpeg_trial6=pandas.read_csv('raw_data/cpu_gstreamer_mjpeg_trail6')
cpu_gstreamer_mjpeg_trial7=pandas.read_csv('raw_data/cpu_gstreamer_mjpeg_trail7')

#memory_gstreamer_mjpeg
memory_gstreamer_mjpeg_trial1=pandas.read_csv('raw_data/memory_gstreamer_mjpeg_trail1')
memory_gstreamer_mjpeg_trial2=pandas.read_csv('raw_data/memory_gstreamer_mjpeg_trail2')
memory_gstreamer_mjpeg_trial3=pandas.read_csv('raw_data/memory_gstreamer_mjpeg_trail3')
memory_gstreamer_mjpeg_trial4=pandas.read_csv('raw_data/memory_gstreamer_mjpeg_trail4')
memory_gstreamer_mjpeg_trial5=pandas.read_csv('raw_data/memory_gstreamer_mjpeg_trail5')
memory_gstreamer_mjpeg_trial6=pandas.read_csv('raw_data/memory_gstreamer_mjpeg_trail6')
memory_gstreamer_mjpeg_trial7=pandas.read_csv('raw_data/memory_gstreamer_mjpeg_trail7')

#network_receive_gstreamer_mjpeg
network_receive_gstreamer_mjpeg_trial1=pandas.read_csv('raw_data/net_recieve_gstreamer_mjpeg_trail1')
network_receive_gstreamer_mjpeg_trial2=pandas.read_csv('raw_data/net_recieve_gstreamer_mjpeg_trail2')
network_receive_gstreamer_mjpeg_trial3=pandas.read_csv('raw_data/net_recieve_gstreamer_mjpeg_trail3')
network_receive_gstreamer_mjpeg_trial4=pandas.read_csv('raw_data/net_recieve_gstreamer_mjpeg_trail4')
network_receive_gstreamer_mjpeg_trial5=pandas.read_csv('raw_data/net_recieve_gstreamer_mjpeg_trail5')
network_receive_gstreamer_mjpeg_trial6=pandas.read_csv('raw_data/net_recieve_gstreamer_mjpeg_trail6')
network_receive_gstreamer_mjpeg_trial7=pandas.read_csv('raw_data/net_recieve_gstreamer_mjpeg_trail7')

#network_transmit_gstreamer_mjpeg
network_transmit_gstreamer_mjpeg_trial1=pandas.read_csv('raw_data/net_transmit_gstreamer_mjpeg_trail1')
network_transmit_gstreamer_mjpeg_trial2=pandas.read_csv('raw_data/net_transmit_gstreamer_mjpeg_trail2')
network_transmit_gstreamer_mjpeg_trial3=pandas.read_csv('raw_data/net_transmit_gstreamer_mjpeg_trail3')
network_transmit_gstreamer_mjpeg_trial4=pandas.read_csv('raw_data/net_transmit_gstreamer_mjpeg_trail4')
network_transmit_gstreamer_mjpeg_trial5=pandas.read_csv('raw_data/net_transmit_gstreamer_mjpeg_trail5')
network_transmit_gstreamer_mjpeg_trial6=pandas.read_csv('raw_data/net_transmit_gstreamer_mjpeg_trail6')
network_transmit_gstreamer_mjpeg_trial7=pandas.read_csv('raw_data/net_transmit_gstreamer_mjpeg_trail7')
