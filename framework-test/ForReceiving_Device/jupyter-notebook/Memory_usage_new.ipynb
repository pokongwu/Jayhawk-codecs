# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
memory_cvlc_h264_trial1=pd.read_csv('raw_data/memory_cvlch264_trial1')
memory_cvlc_h264_trial2=pd.read_csv('raw_data/memory_cvlch264_trial2')
memory_cvlc_h264_trial3=pd.read_csv('raw_data/memory_cvlch264_trial3')
memory_cvlc_h264_trial4=pd.read_csv('raw_data/memory_cvlch264_trial4')
memory_cvlc_h264_trial5=pd.read_csv('raw_data/memory_cvlch264_trial5')
memory_cvlc_h264_trial6=pd.read_csv('raw_data/memory_cvlch264_trial6')
memory_cvlc_h264_trial7=pd.read_csv('raw_data/memory_cvlch264_trial7')
#concat all csv files
memory_cvlc_h264=pd.concat([memory_cvlc_h264_trial1,memory_cvlc_h264_trial2,memory_cvlc_h264_trial3,memory_cvlc_h264_trial4,memory_cvlc_h264_trial5,memory_cvlc_h264_trial6,memory_cvlc_h264_trial7])
#convert timestamp to datetime
memory_cvlc_h264['timestamp']=pd.to_datetime(memory_cvlc_h264['timestamp'],unit='s')
#convert Bytes to Megabytes
memory_cvlc_h264['value']=memory_cvlc_h264['value']/(1000**2)
#plot boxplot
ax1=memory_cvlc_h264.boxplot(by='timestamp',column=['value'],grid=False,figsize=(10,7))
plt.title('memory_cvlc_h264')
plt.ylabel('value')
plt.xticks(horizontalalignment='right',rotation=45)
#print result
result=[memory_cvlc_h264['timestamp'],memory_cvlc_h264['value']]
result
# Out:
# [0   2020-10-02 08:55:08.487000227
#  0   2020-10-02 08:56:18.127999783
#  0   2020-10-02 08:57:20.196000099
#  0   2020-10-02 08:58:24.392999887
#  0   2020-10-02 08:59:38.177000046
#  0   2020-10-02 09:00:38.101000071
#  0   2020-10-02 09:01:48.442000151
#  Name: timestamp, dtype: datetime64[ns],
#  0    127.090688
#  0    126.959616
#  0    128.188416
#  0    127.787008
#  0    128.319488
#  0    128.946176
#  0    128.319488
#  Name: value, dtype: float64]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
memory_cvlc_mjpeg_trial1=pd.read_csv('raw_data/memory_cvlcmjpeg_trial1')
memory_cvlc_mjpeg_trial2=pd.read_csv('raw_data/memory_cvlcmjpeg_trial2')
memory_cvlc_mjpeg_trial3=pd.read_csv('raw_data/memory_cvlcmjpeg_trial3')
memory_cvlc_mjpeg_trial4=pd.read_csv('raw_data/memory_cvlcmjpeg_trial4')
memory_cvlc_mjpeg_trial5=pd.read_csv('raw_data/memory_cvlcmjpeg_trial5')
memory_cvlc_mjpeg_trial6=pd.read_csv('raw_data/memory_cvlcmjpeg_trial6')
memory_cvlc_mjpeg_trial7=pd.read_csv('raw_data/memory_cvlcmjpeg_trial7')
#concat all csv files
memory_cvlc_mjpeg=pd.concat([memory_cvlc_mjpeg_trial1,memory_cvlc_mjpeg_trial2,memory_cvlc_mjpeg_trial3,memory_cvlc_mjpeg_trial4,memory_cvlc_mjpeg_trial5,memory_cvlc_mjpeg_trial6,memory_cvlc_mjpeg_trial7])
#convert timestamp to datetime
memory_cvlc_mjpeg['timestamp']=pd.to_datetime(memory_cvlc_mjpeg['timestamp'],unit='s')
#convert Bytes to Megabytes
memory_cvlc_mjpeg['value']=memory_cvlc_mjpeg['value']/(1000**2)
#plot boxplot
ax2=memory_cvlc_mjpeg.boxplot(by='timestamp',column=['value'],grid=False,figsize=(10,7))
plt.title('memory_cvlc_mjpeg')
plt.ylabel('value')
plt.xticks(horizontalalignment='right',rotation=45)
#print result
result=[memory_cvlc_mjpeg['timestamp'],memory_cvlc_mjpeg['value']]
result
# Out:
# [0   2020-09-24 17:07:04.095999956
#  0   2020-09-24 17:08:23.194000006
#  0   2020-09-24 17:09:33.833999872
#  0   2020-09-24 17:10:54.292999983
#  0   2020-09-24 17:11:59.761000156
#  0   2020-09-24 17:13:04.572000027
#  0   2020-09-24 17:14:13.904999971
#  Name: timestamp, dtype: datetime64[ns],
#  0    126.652416
#  0    149.196800
#  0     40.312832
#  0     45.281280
#  0    344.473600
#  0    203.681792
#  0    149.794816
#  Name: value, dtype: float64]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
memory_ffmpeg_h264_trial1=pd.read_csv('raw_data/memory_ffmpeg_h264_trial1')
memory_ffmpeg_h264_trial2=pd.read_csv('raw_data/memory_ffmpeg_h264_trial2')
memory_ffmpeg_h264_trial3=pd.read_csv('raw_data/memory_ffmpeg_h264_trial3')
memory_ffmpeg_h264_trial4=pd.read_csv('raw_data/memory_ffmpeg_h264_trial4')
memory_ffmpeg_h264_trial5=pd.read_csv('raw_data/memory_ffmpeg_h264_trial5')
memory_ffmpeg_h264_trial6=pd.read_csv('raw_data/memory_ffmpeg_h264_trial6')
memory_ffmpeg_h264_trial7=pd.read_csv('raw_data/memory_ffmpeg_h264_trial7')
#concat all csv files
memory_ffmpeg_h264=pd.concat([memory_ffmpeg_h264_trial1,memory_ffmpeg_h264_trial2,memory_ffmpeg_h264_trial3,memory_ffmpeg_h264_trial4,memory_ffmpeg_h264_trial5,memory_ffmpeg_h264_trial6,memory_ffmpeg_h264_trial7])
#convert timestamp to datetime
memory_ffmpeg_h264['timestamp']=pd.to_datetime(memory_ffmpeg_h264['timestamp'],unit='s')
#convert Bytes to Megabytes
memory_ffmpeg_h264['value']=memory_ffmpeg_h264['value']/(1000**2)
#plot boxplot
ax3=memory_ffmpeg_h264.boxplot(by='timestamp',column=['value'],grid=False,figsize=(10,7))
plt.title('memory_ffmpeg_h264')
plt.ylabel('value')
plt.xticks(horizontalalignment='right',rotation=45)
#print result
result=[memory_ffmpeg_h264['timestamp'],memory_ffmpeg_h264['value']]
result
# Out:
# [0   2020-10-02 09:44:30.252000092
#  0   2020-10-02 09:45:33.847999811
#  0   2020-10-02 09:46:43.400000095
#  0   2020-10-02 09:47:50.845000029
#  0   2020-10-02 09:48:55.621000051
#  0   2020-10-02 09:49:58.827999830
#  0   2020-10-02 09:51:19.401000023
#  Name: timestamp, dtype: datetime64[ns],
#  0    59.232256
#  0    59.232256
#  0    59.232256
#  0    59.232256
#  0    59.244544
#  0    59.244544
#  0    59.244544
#  Name: value, dtype: float64]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
memory_ffmpeg_mjpeg_trial1=pd.read_csv('raw_data/memory_ffmpegmjpeg_trial1')
memory_ffmpeg_mjpeg_trial2=pd.read_csv('raw_data/memory_ffmpegmjpeg_trial2')
memory_ffmpeg_mjpeg_trial3=pd.read_csv('raw_data/memory_ffmpegmjpeg_trial3')
memory_ffmpeg_mjpeg_trial4=pd.read_csv('raw_data/memory_ffmpegmjpeg_trial4')
memory_ffmpeg_mjpeg_trial5=pd.read_csv('raw_data/memory_ffmpegmjpeg_trial5')
memory_ffmpeg_mjpeg_trial6=pd.read_csv('raw_data/memory_ffmpegmjpeg_trial6')
memory_ffmpeg_mjpeg_trial7=pd.read_csv('raw_data/memory_ffmpegmjpeg_trial7')
#concat all csv files
memory_ffmpeg_mjpeg=pd.concat([memory_ffmpeg_mjpeg_trial1,memory_ffmpeg_mjpeg_trial2,memory_ffmpeg_mjpeg_trial3,memory_ffmpeg_mjpeg_trial4,memory_ffmpeg_mjpeg_trial5,memory_ffmpeg_mjpeg_trial6,memory_ffmpeg_mjpeg_trial7])
#convert timestamp to datetime
memory_ffmpeg_mjpeg['timestamp']=pd.to_datetime(memory_ffmpeg_mjpeg['timestamp'],unit='s')
#convert Bytes to Megabytes
memory_ffmpeg_mjpeg['value']=memory_ffmpeg_mjpeg['value']/(1000**2)
#plot boxplot
ax4=memory_ffmpeg_mjpeg.boxplot(by='timestamp',column=['value'],grid=False,figsize=(10,7))
plt.title('memory_ffmpeg_mjpeg')
plt.ylabel('value')
plt.xticks(horizontalalignment='right',rotation=45)
#print result
result=[memory_ffmpeg_mjpeg['timestamp'],memory_ffmpeg_mjpeg['value']]
result
# Out:
# [0   2020-09-29 12:42:16.967999935
#  0   2020-09-29 12:43:27.622000217
#  0   2020-09-29 12:44:51.569999933
#  0   2020-09-29 12:46:07.407000065
#  0   2020-09-29 12:46:58.418999910
#  0   2020-09-29 12:47:59.734999895
#  0   2020-09-29 12:49:00.813999891
#  Name: timestamp, dtype: datetime64[ns],
#  0    12.865536
#  0    12.865536
#  0    12.865536
#  0    12.865536
#  0    12.865536
#  0    12.865536
#  0    12.865536
#  Name: value, dtype: float64]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
memory_mjpgstreamer_trial1=pd.read_csv('raw_data/memory_mjpgstreamer_trail1')
memory_mjpgstreamer_trial2=pd.read_csv('raw_data/memory_mjpgstreamer_trail2')
memory_mjpgstreamer_trial3=pd.read_csv('raw_data/memory_mjpgstreamer_trail3')
memory_mjpgstreamer_trial4=pd.read_csv('raw_data/memory_mjpgstreamer_trail4')
memory_mjpgstreamer_trial5=pd.read_csv('raw_data/memory_mjpgstreamer_trail5')
memory_mjpgstreamer_trial6=pd.read_csv('raw_data/memory_mjpgstreamer_trail6')
memory_mjpgstreamer_trial7=pd.read_csv('raw_data/memory_mjpgstreamer_trail7')
#concat all csv files
memory_mjpgstreamer=pd.concat([memory_mjpgstreamer_trial1,memory_mjpgstreamer_trial2,memory_mjpgstreamer_trial3,memory_mjpgstreamer_trial4,memory_mjpgstreamer_trial5,memory_mjpgstreamer_trial6,memory_mjpgstreamer_trial7],axis=0)
#convert timestamp to datetime
memory_mjpgstreamer['timestamp']=pd.to_datetime(memory_mjpgstreamer['timestamp'],unit='s')
#convert Bytes to Megabytes
memory_mjpgstreamer['value']=memory_mjpgstreamer['value']/(1000**2)
#plot boxplot
ax5=memory_mjpgstreamer.boxplot(by='timestamp',column=['value'],grid=False,figsize=(10,7))
plt.title('memory_mjpgstreamer')
plt.ylabel('value')
plt.xticks(horizontalalignment='right',rotation=45)
#print result
result=[memory_mjpgstreamer['timestamp'],memory_mjpgstreamer['value']]
result
# Out:
# [0   2020-09-28 12:10:22.095000029
#  0   2020-09-28 12:11:25.519999981
#  0   2020-09-28 12:12:33.783999920
#  0   2020-09-28 12:13:41.414999962
#  0   2020-09-28 12:14:43.571000099
#  0   2020-09-28 12:15:48.650000095
#  0   2020-09-28 12:16:53.466000080
#  Name: timestamp, dtype: datetime64[ns],
#  0    1.675264
#  0    1.675264
#  0    1.675264
#  0    1.679360
#  0    1.679360
#  0    1.679360
#  0    1.679360
#  Name: value, dtype: float64]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
memory_gstreamer_h264_trial1=pd.read_csv('raw_data/memory_gstreamerh264_trail1')
memory_gstreamer_h264_trial2=pd.read_csv('raw_data/memory_gstreamerh264_trail2')
memory_gstreamer_h264_trial3=pd.read_csv('raw_data/memory_gstreamerh264_trail3')
memory_gstreamer_h264_trial4=pd.read_csv('raw_data/memory_gstreamerh264_trail4')
memory_gstreamer_h264_trial5=pd.read_csv('raw_data/memory_gstreamerh264_trail5')
memory_gstreamer_h264_trial6=pd.read_csv('raw_data/memory_gstreamerh264_trail6')
memory_gstreamer_h264_trial7=pd.read_csv('raw_data/memory_gstreamerh264_trail7')
#concat all csv files
memory_gstreamer_h264=pd.concat([memory_gstreamer_h264_trial1,memory_gstreamer_h264_trial2,memory_gstreamer_h264_trial3,memory_gstreamer_h264_trial4,memory_gstreamer_h264_trial5,memory_gstreamer_h264_trial6,memory_gstreamer_h264_trial7],axis=0)
#convert timestamp to datetime
memory_gstreamer_h264['timestamp']=pd.to_datetime(memory_gstreamer_h264['timestamp'],unit='s')
#convert Bytes to Megabytes
memory_gstreamer_h264['value']=memory_gstreamer_h264['value']/(1000**2)
#plot boxplot
ax6=memory_gstreamer_h264.boxplot(by='timestamp',column=['value'],grid=False,figsize=(10,7))
plt.title('memory_gstreamer_h264')
plt.ylabel('value')
plt.xticks(horizontalalignment='right',rotation=45)
#print result
result=[memory_gstreamer_h264['timestamp'],memory_gstreamer_h264['value']]
result
# Out:
# [0   2020-09-28 13:40:27.898999929
#  0   2020-09-28 13:41:32.831000090
#  0   2020-09-28 13:42:36.578999996
#  0   2020-09-28 13:43:40.383999825
#  0   2020-09-28 13:44:43.988999844
#  0   2020-09-28 13:45:47.577999830
#  0   2020-09-28 13:46:50.387000084
#  Name: timestamp, dtype: datetime64[ns],
#  0    45.027328
#  0    45.027328
#  0    45.027328
#  0    45.027328
#  0    45.027328
#  0    45.027328
#  0    45.027328
#  Name: value, dtype: float64]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
memory_gstreamer_mjpeg_trial1=pd.read_csv('raw_data/memory_gstreamer_mjpeg_trail1')
memory_gstreamer_mjpeg_trial2=pd.read_csv('raw_data/memory_gstreamer_mjpeg_trail2')
memory_gstreamer_mjpeg_trial3=pd.read_csv('raw_data/memory_gstreamer_mjpeg_trail3')
memory_gstreamer_mjpeg_trial4=pd.read_csv('raw_data/memory_gstreamer_mjpeg_trail4')
memory_gstreamer_mjpeg_trial5=pd.read_csv('raw_data/memory_gstreamer_mjpeg_trail5')
memory_gstreamer_mjpeg_trial6=pd.read_csv('raw_data/memory_gstreamer_mjpeg_trail6')
memory_gstreamer_mjpeg_trial7=pd.read_csv('raw_data/memory_gstreamer_mjpeg_trail7')
#concat all csv files
memory_gstreamer_mjpeg=pd.concat([memory_gstreamer_mjpeg_trial1,memory_gstreamer_mjpeg_trial2,memory_gstreamer_mjpeg_trial3,memory_gstreamer_mjpeg_trial4,memory_gstreamer_mjpeg_trial5,memory_gstreamer_mjpeg_trial6,memory_gstreamer_mjpeg_trial7],axis=0)
#convert timestamp to datetime
memory_gstreamer_mjpeg['timestamp']=pd.to_datetime(memory_gstreamer_mjpeg['timestamp'],unit='s')
#convert Bytes to Megabytes
memory_gstreamer_mjpeg['value']=memory_gstreamer_mjpeg['value']/(1000**2)
#plot boxplot
ax7=memory_gstreamer_mjpeg.boxplot(by='timestamp',column=['value'],grid=False,figsize=(10,7))
plt.title('memory_gstreamer_mjpeg')
plt.ylabel('value')
plt.xticks(horizontalalignment='right',rotation=45)
#print result
result=[memory_gstreamer_mjpeg['timestamp'],memory_gstreamer_mjpeg['value']]
result
# Out:
# [0   2020-09-28 14:29:30.082999945
#  0   2020-09-28 14:30:33.072000027
#  0   2020-09-28 14:31:38.117999792
#  0   2020-09-28 14:32:40.976000071
#  0   2020-09-28 14:33:46.019999981
#  0   2020-09-28 14:34:49.892000198
#  0   2020-09-28 14:35:53.352999926
#  Name: timestamp, dtype: datetime64[ns],
#  0    7.839744
#  0    7.880704
#  0    7.958528
#  0    7.868416
#  0    7.860224
#  0    7.921664
#  0    7.856128
#  Name: value, dtype: float64]

# %%
#grouped boxplot for all frameworks
plt.boxplot([ax1,ax2,ax3,ax4,ax5,ax6,ax7])
plt.title('memory_usage')
plt.ylabel('value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-79a5a06645cf> in <module>
# ----> 1 plt.boxplot([ax1,ax2,ax3,ax4,ax5,ax6,ax7])
#       2 plt.title('memory_usage')
#       3 plt.ylabel('value')
#       4 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2435         whiskerprops=None, manage_ticks=True, autorange=False,
#    2436         zorder=None, *, data=None):
# -> 2437     return gca().boxplot(
#    2438         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2439         positions=positions, widths=widths, patch_artist=patch_artist,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     294                 f"for the old name will be dropped %(removal)s.")
#     295             kwargs[new] = kwargs.pop(old)
# --> 296         return func(*args, **kwargs)
#     297
#     298     # wrapper() must keep the same documented signature as func(): if we
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3625             bootstrap = rcParams['boxplot.bootstrap']
#    3626
# -> 3627         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3628                                        labels=labels, autorange=autorange)
#    3629         if notch is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1203
#    1204         # arithmetic mean
# -> 1205         stats['mean'] = np.mean(x)
#    1206
#    1207         # medians and quartiles
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3332             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3333
# -> 3334     return _methods._mean(a, axis=axis, dtype=dtype,
#    3335                           out=out, **kwargs)
#    3336
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# TypeError: unsupported operand type(s) for +: 'AxesSubplot' and 'AxesSubplot'
