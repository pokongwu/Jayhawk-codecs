# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
network_receive_cvlc_h264=pd.read_csv('net_rx_cvlch264_mod.csv')
#dataframe to retrieve column value
df1=pd.DataFrame(network_receive_cvlc_h264,columns=['value'])
#convert Bytes to Megabytes
df1['value']=df1['value']/(1000**2)
value1=df1['value']
#plot boxplot
plt.boxplot(value1)
plt.title('network_receive_cvlc_h264')
plt.ylabel('value_in_MB')
plt.show()
value1
# Out:
# 0    16.443935
# 1    16.974061
# 2    17.324311
# 3    17.717196
# 4    18.217989
# 5    18.609014
# 6    18.977185
# Name: value, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
network_receive_cvlc_mjpeg=pd.read_csv('net_rx_cvlcmjpeg.csv')
#dataframe to retrieve column value
df2=pd.DataFrame(network_receive_cvlc_mjpeg,columns=['value'])
#convert Bytes to Megabytes
df2['value']=df2['value']/(1000**2)
value2=df2['value']
#plot boxplot
plt.boxplot(value2)
plt.title('network_receive_cvlc_mjpeg')
plt.ylabel('value_in_MB')
plt.show()
value2
# Out:
# 0    3.576650
# 1    3.597363
# 2    3.624916
# 3    3.654548
# 4    3.684832
# 5    3.713150
# 6    3.733882
# Name: value, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
network_receive_ffmpeg_h264=pd.read_csv('net_rx_ffmpegh264_mod.csv')
#dataframe to retrieve column value
df3=pd.DataFrame(network_receive_ffmpeg_h264,columns=['value'])
#convert Bytes to Megabytes
df3['value']=df3['value']/(1000**2)
value3=df3['value']
#plot boxplot
plt.boxplot(value3)
plt.title('network_receive_ffmpeg_h264')
plt.ylabel('value_in_MB')
plt.show()
value3
# Out:
# 0    41.630241
# 1    41.768763
# 2    41.875502
# 3    42.027208
# 4    42.186412
# 5    42.484194
# 6    42.715528
# Name: value, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
network_receive_ffmpeg_mjpeg=pd.read_csv('net_rx_ffmpegmjpeg_mod.csv')
#dataframe to retrieve column value
df4=pd.DataFrame(network_receive_ffmpeg_mjpeg,columns=['value'])
#convert Bytes to Megabytes
df4['value']=df4['value']/(1000**2)
value4=df4['value']
#plot boxplot
plt.boxplot(value4)
plt.title('network_receive_ffmpeg_mjpeg')
plt.ylabel('value_in_MB')
plt.show()
value4
# Out:
# 0    56.629736
# 1    56.794586
# 2    56.913936
# 3    57.116627
# 4    57.237136
# 5    57.375068
# 6    57.481261
# Name: value, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
network_receive_mjpgstreamer=pd.read_csv('network_rx_mjpgstreamer_mod.csv')
#dataframe to retrieve column value
df5=pd.DataFrame(network_receive_mjpgstreamer,columns=['value'])
#convert Bytes to Megabytes
df5['value']=df5['value']/(1000**2)
value5=df5['value']
#plot boxplot
plt.boxplot(value5)
plt.title('network_receive_mjpgstreamer')
plt.ylabel('value_in_MB')
plt.show()
value5
# Out:
# 0     95.884213
# 1     97.838561
# 2     99.451799
# 3    101.478045
# 4    102.888181
# 5    104.899942
# 6    106.485986
# Name: value, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
network_receive_gstreamer_h264=pd.read_csv('net_rx_gstreamerh264_mod.csv')
#dataframe to retrieve column value
df6=pd.DataFrame(network_receive_gstreamer_h264,columns=['value'])
#convert Bytes to Megabytes
df6['value']=df6['value']/(1000**2)
value6=df6['value']
#plot boxplot
plt.boxplot(value6)
plt.title('network_receive_gstreamer_h264')
plt.ylabel('value_in_MB')
plt.show()
value6
# Out:
# 0    132.861528
# 1    134.539971
# 2    135.065076
# 3    135.671804
# 4    136.291669
# 5    136.845318
# 6    137.561233
# Name: value, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import a csv file
network_receive_gstreamer_mjpeg=pd.read_csv('net_rx_gstreamermjpeg_mod.csv')
#dataframe to retrieve column value
df7=pd.DataFrame(network_receive_gstreamer_mjpeg,columns=['value'])
#convert Bytes to Megabytes
df7['value']=df7['value']/(1000**2)
value7=df7['value']
#plot boxplot
plt.boxplot(value7)
plt.title('network_receive_gstreamer_mjpeg')
plt.ylabel('value_in_MB')
plt.show()
value7
# Out:
# 0    150.352815
# 1    150.439743
# 2    150.547728
# 3    150.699742
# 4    150.849919
# 5    150.941283
# 6    151.342422
# Name: value, dtype: float64

# %%
#grouped boxplot for all frameworks
result=[value1,value2,value3,value4,value5,value6,value7]
plt.boxplot(result)
plt.title('network_receive')
plt.ylabel('value_in_MB')
plt.show()
